# %%
import os
from google import genai
from google.genai import types

# %%
google_api_key = os.getenv("GEMINI_API_KEY")

# %%
client = genai.Client(api_key=google_api_key)
config = types.GenerateContentConfig(
    temperature=1.0,
)
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Act as a support agent. A customer says: ‘I was charged twice for the same item. What should I do?’",
    config=config
)

print(response.text)
# Out:
# Oh no, I'm really sorry to hear that you've been charged twice for the same item. That's definitely not right, and I understand how frustrating that can be.
#
# Don't worry, we can certainly look into this for you and get it resolved.
#
# To help me investigate this and initiate a refund for the duplicate charge, could you please provide me with the following details?
#
# *   **The order number(s)** for the item (if you have them).
# *   **The date(s)** the charges appeared on your statement.
# *   **The exact amount** of each charge.
# *   **The name of the item** purchased.
# *   **The payment method** you used (e.g., Visa, Mastercard, PayPal).
# *   **Where you're seeing the duplicate charge** (e.g., bank statement, our app's order history).
#
# Once I have this information, I can cross-reference it with our system, identify the duplicate charge, and initiate the necessary refund for you. We'll make sure this gets sorted out.

# %%
genai.models
# Out:
# <module 'google.genai.models' from 'c:\\Projects_GIT\\llm-api-playground\\.venv\\Lib\\site-packages\\google\\genai\\models.py'>
